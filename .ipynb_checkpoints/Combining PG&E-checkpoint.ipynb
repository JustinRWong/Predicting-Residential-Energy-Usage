# %%
# !ls data
# Out:
# Bay Area Zip Codes + City Name - Sheet1.csv
# PGE

# %%
import pandas as pd
import numpy as np
import os
import pprint as pp
import geopandas as gpd


# !pip install geopandas

# %%
pge_path = 'data/PGE'
# !ls data/PGE
# Out:
# 2013 2014 2015 2016 2017 2018 2019 2020

# %%
pd.read_csv('data/PGE/2020/PGE_2020_Q1_ElectricUsageByZip.csv')
# Out:
#       ZIPCODE  MONTH  YEAR       CUSTOMERCLASS COMBINED TOTALCUSTOMERS  \
# 0       93101      1  2020  Elec- Agricultural        Y              0
# 1       93101      2  2020  Elec- Agricultural        Y              0
# 2       93101      3  2020  Elec- Agricultural        Y              0
# 3       93110      1  2020  Elec- Agricultural        Y              0
# 4       93110      2  2020  Elec- Agricultural        Y              0
# ...       ...    ...   ...                 ...      ...            ...
# 7860    96137      2  2020   Elec- Residential        N          2,753
# 7861    96137      3  2020   Elec- Residential        N          2,754
# 7862    96162      1  2020   Elec- Residential        Y              0
# 7863    96162      2  2020   Elec- Residential        Y              0
# 7864    96162      3  2020   Elec- Residential        Y              0
#
#      TOTALKWH AVERAGEKWH
# 0           0        NaN
# 1           0        NaN
# 2           0        NaN
# 3           0        NaN
# 4           0        NaN
# ...       ...        ...
# 7860  838,616        305
# 7861  942,125        342
# 7862        0        NaN
# 7863        0        NaN
# 7864        0        NaN
#
# [7865 rows x 8 columns]

# %%
pd.read_csv('data/PGE/2013/PGE_2013_Q1_GasUsageByZip.csv')
# Out:
#       ZipCode  Month  Year     CustomerClass Combined TotalCustomers TotalThm  \
# 0       92304      1  2013   Gas- Commercial        Y              0        0
# 1       92304      2  2013   Gas- Commercial        Y              0        0
# 2       92304      3  2013   Gas- Commercial        Y              0        0
# 3       92365      1  2013   Gas- Commercial        Y              0        0
# 4       92365      2  2013   Gas- Commercial        Y              0        0
# ...       ...    ...   ...               ...      ...            ...      ...
# 3478    96088      2  2013  Gas- Residential        Y              0        0
# 3479    96088      3  2013  Gas- Residential        Y              0        0
# 3480    96090      1  2013  Gas- Residential        N            148   11,489
# 3481    96090      2  2013  Gas- Residential        N            148    7,408
# 3482    96090      3  2013  Gas- Residential        N            149    4,617
#
#      AverageThm
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 3478        NaN
# 3479        NaN
# 3480         78
# 3481         50
# 3482         31
#
# [3483 rows x 8 columns]

# %%
## concatenates the path and fn
def full_path(path, fn):
    return path + "/" + fn

def open_csv_and_merge_to_df(df, fn, log=False):
    if log:
        print("Attempting to open: ", fn)
        
    ## Ensure opening a file with the .csv extension
    assert fn[-4:] == '.csv'
    fn_df = pd.read_csv(fn)
    
    fn_df_rows_count = fn_df.shape[0]
    print("\t\t   {s} rows found".format(s=fn_df_rows_count))
    
    ## convert all columns to upper case to combine
    ## this ensures that 'ZIPCODE' and 'ZipCode' are recognized as the same column when appended
    fn_df.columns = [c.upper() for c in fn_df.columns] 
    
    return df.append(fn_df).reset_index(drop=True), fn_df_rows_count

def parse_pge_csv(pge_csv_fn):
    ## Assumes pge_csv_fn follows this format: 'PGE_YYYY_Q{1-4}_{Electric or Gas}UsageByZip.csv'
    pge, year, quarter, utility = pge_csv_fn.split('_')
    u = utility.split('UsageByZip.csv')[0] ## Gas or Electric
    s = "{y}_{q}_{u}".format(y=year, q=quarter, u=u)
    print("\t\t   {s} parsed.".format(s=s))
    return s

# %%
base_df = pd.DataFrame() ## Must start base_df from scratch in order to not have duplicate data
quarterly_rows_count = {}

## Open each year and quarter in chronological order and build the dataframe
for year in sorted(os.listdir(pge_path)):
    pge_data_year = full_path(pge_path, year)
    print("Extracting Contents for year: {y}".format(y=year))
    print("\tOpening: {p}".format(p=pge_data_year))
    
    for pge_year_q in sorted(os.listdir(pge_data_year)):
        ## only build the csv files
        if pge_year_q[-4:] == ".csv":
            pge_year_q_fn = full_path(pge_data_year, pge_year_q)
            print("\t\t>{fn}".format(fn=pge_year_q_fn))
            
            base_df, pge_year_q_rows = open_csv_and_merge_to_df(base_df, pge_year_q_fn)
            k = parse_pge_csv(pge_year_q)
            quarterly_rows_count[k] = pge_year_q_rows
            
    print("\n")
# Out:
# Extracting Contents for year: 2013
# 	Opening: data/PGE/2013
# 		>data/PGE/2013/PGE_2013_Q1_ElectricUsageByZip.csv
# 		   7521 rows found
# 		   2013_Q1_Electric parsed.
# 		>data/PGE/2013/PGE_2013_Q1_GasUsageByZip.csv
# 		   3483 rows found
# 		   2013_Q1_Gas parsed.
# 		>data/PGE/2013/PGE_2013_Q2_ElectricUsageByZip.csv
# 		   7576 rows found
# 		   2013_Q2_Electric parsed.
# 		>data/PGE/2013/PGE_2013_Q2_GasUsageByZip.csv
# 		   3481 rows found
# 		   2013_Q2_Gas parsed.
# 		>data/PGE/2013/PGE_2013_Q3_ElectricUsageByZip.csv
# 		   7604 rows found
# 		   2013_Q3_Electric parsed.
# 		>data/PGE/2013/PGE_2013_Q3_GasUsageByZip.csv
# 		   3483 rows found
# 		   2013_Q3_Gas parsed.
# 		>data/PGE/2013/PGE_2013_Q4_ElectricUsageByZip.csv
# 		   7658 rows found
# 		   2013_Q4_Electric parsed.
# 		>data/PGE/2013/PGE_2013_Q4_GasUsageByZip.csv
# 		   3482 rows found
# 		   2013_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2014
# 	Opening: data/PGE/2014
# 		>data/PGE/2014/PGE_2014_Q1_ElectricUsageByZip.csv
# 		   7683 rows found
# 		   2014_Q1_Electric parsed.
# 		>data/PGE/2014/PGE_2014_Q1_GasUsageByZip.csv
# 		   3481 rows found
# 		   2014_Q1_Gas parsed.
# 		>data/PGE/2014/PGE_2014_Q2_ElectricUsageByZip.csv
# 		   7694 rows found
# 		   2014_Q2_Electric parsed.
# 		>data/PGE/2014/PGE_2014_Q2_GasUsageByZip.csv
# 		   3483 rows found
# 		   2014_Q2_Gas parsed.
# 		>data/PGE/2014/PGE_2014_Q3_ElectricUsageByZip.csv
# 		   30718 rows found
# 		   2014_Q3_Electric parsed.
# 		>data/PGE/2014/PGE_2014_Q3_GasUsageByZip.csv
# 		   13938 rows found
# 		   2014_Q3_Gas parsed.
# 		>data/PGE/2014/PGE_2014_Q4_ElectricUsageByZip.csv
# 		   7675 rows found
# 		   2014_Q4_Electric parsed.
# 		>data/PGE/2014/PGE_2014_Q4_GasUsageByZip.csv
# 		   3491 rows found
# 		   2014_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2015
# 	Opening: data/PGE/2015
# 		>data/PGE/2015/PGE_2015_Q1_ElectricUsageByZip.csv
# 		   7691 rows found
# 		   2015_Q1_Electric parsed.
# 		>data/PGE/2015/PGE_2015_Q1_GasUsageByZip.csv
# 		   3486 rows found
# 		   2015_Q1_Gas parsed.
# 		>data/PGE/2015/PGE_2015_Q2_ElectricUsageByZip.csv
# 		   7735 rows found
# 		   2015_Q2_Electric parsed.
# 		>data/PGE/2015/PGE_2015_Q2_GasUsageByZip.csv
# 		   3486 rows found
# 		   2015_Q2_Gas parsed.
# 		>data/PGE/2015/PGE_2015_Q3_ElectricUsageByZip.csv
# 		   7756 rows found
# 		   2015_Q3_Electric parsed.
# 		>data/PGE/2015/PGE_2015_Q3_GasUsageByZip.csv
# 		   3487 rows found
# 		   2015_Q3_Gas parsed.
# 		>data/PGE/2015/PGE_2015_Q4_ElectricUsageByZip.csv
# 		   7748 rows found
# 		   2015_Q4_Electric parsed.
# 		>data/PGE/2015/PGE_2015_Q4_GasUsageByZip.csv
# 		   3487 rows found
# 		   2015_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2016
# 	Opening: data/PGE/2016
# 		>data/PGE/2016/PGE_2016_Q1_ElectricUsageByZip.csv
# 		   7755 rows found
# 		   2016_Q1_Electric parsed.
# 		>data/PGE/2016/PGE_2016_Q1_GasUsageByZip.csv
# 		   3490 rows found
# 		   2016_Q1_Gas parsed.
# 		>data/PGE/2016/PGE_2016_Q2_ElectricUsageByZip.csv
# 		   7770 rows found
# 		   2016_Q2_Electric parsed.
# 		>data/PGE/2016/PGE_2016_Q2_GasUsageByZip.csv
# 		   3487 rows found
# 		   2016_Q2_Gas parsed.
# 		>data/PGE/2016/PGE_2016_Q3_ElectricUsageByZip.csv
# 		   7776 rows found
# 		   2016_Q3_Electric parsed.
# 		>data/PGE/2016/PGE_2016_Q3_GasUsageByZip.csv
# 		   3703 rows found
# 		   2016_Q3_Gas parsed.
# 		>data/PGE/2016/PGE_2016_Q4_ElectricUsageByZip.csv
# 		   7774 rows found
# 		   2016_Q4_Electric parsed.
# 		>data/PGE/2016/PGE_2016_Q4_GasUsageByZip.csv
# 		   3691 rows found
# 		   2016_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2017
# 	Opening: data/PGE/2017
# 		>data/PGE/2017/PGE_2017_Q1_ElectricUsageByZip.csv
# 		   7776 rows found
# 		   2017_Q1_Electric parsed.
# 		>data/PGE/2017/PGE_2017_Q1_GasUsageByZip.csv
# 		   3486 rows found
# 		   2017_Q1_Gas parsed.
# 		>data/PGE/2017/PGE_2017_Q2_ElectricUsageByZip.csv
# 		   7819 rows found
# 		   2017_Q2_Electric parsed.
# 		>data/PGE/2017/PGE_2017_Q2_GasUsageByZip.csv
# 		   3489 rows found
# 		   2017_Q2_Gas parsed.
# 		>data/PGE/2017/PGE_2017_Q3_ElectricUsageByZip.csv
# 		   7842 rows found
# 		   2017_Q3_Electric parsed.
# 		>data/PGE/2017/PGE_2017_Q3_GasUsageByZip.csv
# 		   3491 rows found
# 		   2017_Q3_Gas parsed.
# 		>data/PGE/2017/PGE_2017_Q4_ElectricUsageByZip.csv
# 		   10455 rows found
# 		   2017_Q4_Electric parsed.
# 		>data/PGE/2017/PGE_2017_Q4_GasUsageByZip.csv
# 		   4662 rows found
# 		   2017_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2018
# 	Opening: data/PGE/2018
# 		>data/PGE/2018/PGE_2018_Q1_ElectricUsageByZip.csv
# 		   7852 rows found
# 		   2018_Q1_Electric parsed.
# 		>data/PGE/2018/PGE_2018_Q1_GasUsageByZip.csv
# 		   3499 rows found
# 		   2018_Q1_Gas parsed.
# 		>data/PGE/2018/PGE_2018_Q2_ElectricUsageByZip.csv
# 		   7880 rows found
# 		   2018_Q2_Electric parsed.
# 		>data/PGE/2018/PGE_2018_Q2_GasUsageByZip.csv
# 		   3502 rows found
# 		   2018_Q2_Gas parsed.
# 		>data/PGE/2018/PGE_2018_Q3_ElectricUsageByZip.csv
# 		   7877 rows found
# 		   2018_Q3_Electric parsed.
# 		>data/PGE/2018/PGE_2018_Q3_GasUsageByZip.csv
# 		   3503 rows found
# 		   2018_Q3_Gas parsed.
# 		>data/PGE/2018/PGE_2018_Q4_ElectricUsageByZip.csv
# 		   7875 rows found
# 		   2018_Q4_Electric parsed.
# 		>data/PGE/2018/PGE_2018_Q4_GasUsageByZip.csv
# 		   3496 rows found
# 		   2018_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2019
# 	Opening: data/PGE/2019
# 		>data/PGE/2019/PGE_2019_Q1_ElectricUsageByZip.csv
# 		   7870 rows found
# 		   2019_Q1_Electric parsed.
# 		>data/PGE/2019/PGE_2019_Q1_GasUsageByZip.csv
# 		   3499 rows found
# 		   2019_Q1_Gas parsed.
# 		>data/PGE/2019/PGE_2019_Q2_ElectricUsageByZip.csv
# 		   7887 rows found
# 		   2019_Q2_Electric parsed.
# 		>data/PGE/2019/PGE_2019_Q2_GasUsageByZip.csv
# 		   3499 rows found
# 		   2019_Q2_Gas parsed.
# 		>data/PGE/2019/PGE_2019_Q3_ElectricUsageByZip.csv
# 		   7891 rows found
# 		   2019_Q3_Electric parsed.
# 		>data/PGE/2019/PGE_2019_Q3_GasUsageByZip.csv
# 		   3489 rows found
# 		   2019_Q3_Gas parsed.
# 		>data/PGE/2019/PGE_2019_Q4_ElectricUsageByZip.csv
# 		   7874 rows found
# 		   2019_Q4_Electric parsed.
# 		>data/PGE/2019/PGE_2019_Q4_GasUsageByZip.csv
# 		   3490 rows found
# 		   2019_Q4_Gas parsed.
#
#
# Extracting Contents for year: 2020
# 	Opening: data/PGE/2020
# 		>data/PGE/2020/PGE_2020_Q1_ElectricUsageByZip.csv
# 		   7865 rows found
# 		   2020_Q1_Electric parsed.
# 		>data/PGE/2020/PGE_2020_Q1_GasUsageByZip.csv
# 		   3493 rows found
# 		   2020_Q1_Gas parsed.
# 		>data/PGE/2020/PGE_2020_Q2_ElectricUsageByZip.csv
# 		   7791 rows found
# 		   2020_Q2_Electric parsed.
# 		>data/PGE/2020/PGE_2020_Q2_GasUsageByZip.csv
# 		   3461 rows found
# 		   2020_Q2_Gas parsed.
# 		>data/PGE/2020/PGE_2020_Q3_ElectricUsageByZip.csv
# 		   7784 rows found
# 		   2020_Q3_Electric parsed.
# 		>data/PGE/2020/PGE_2020_Q3_GasUsageByZip.csv
# 		   3459 rows found
# 		   2020_Q3_Gas parsed.
# 		>data/PGE/2020/PGE_2020_Q4_ElectricUsageByZip.csv
# 		   7771 rows found
# 		   2020_Q4_Electric parsed.
# 		>data/PGE/2020/PGE_2020_Q4_GasUsageByZip.csv
# 		   3456 rows found
# 		   2020_Q4_Gas parsed.

# %%
# pp.pprint(quarterly_rows_count)
## Sanity check to ensure that all rows read in the individual dataframes are in the base_df cumulatively
print("rows in base df: ", base_df.shape)
print("values summed individually: ", sum(quarterly_rows_count.values()))
quarterly_rows_count
# Out:
# rows in base df:  (397856, 12)
# values summed individually:  397856
# {'2013_Q1_Electric': 7521,
#  '2013_Q1_Gas': 3483,
#  '2013_Q2_Electric': 7576,
#  '2013_Q2_Gas': 3481,
#  '2013_Q3_Electric': 7604,
#  '2013_Q3_Gas': 3483,
#  '2013_Q4_Electric': 7658,
#  '2013_Q4_Gas': 3482,
#  '2014_Q1_Electric': 7683,
#  '2014_Q1_Gas': 3481,
#  '2014_Q2_Electric': 7694,
#  '2014_Q2_Gas': 3483,
#  '2014_Q3_Electric': 30718,
#  '2014_Q3_Gas': 13938,
#  '2014_Q4_Electric': 7675,
#  '2014_Q4_Gas': 3491,
#  '2015_Q1_Electric': 7691,
#  '2015_Q1_Gas': 3486,
#  '2015_Q2_Electric': 7735,
#  '2015_Q2_Gas': 3486,
#  '2015_Q3_Electric': 7756,
#  '2015_Q3_Gas': 3487,
#  '2015_Q4_Electric': 7748,
#  '2015_Q4_Gas': 3487,
#  '2016_Q1_Electric': 7755,
#  '2016_Q1_Gas': 3490,
#  '2016_Q2_Electric': 7770,
#  '2016_Q2_Gas': 3487,
#  '2016_Q3_Electric': 7776,
#  '2016_Q3_Gas': 3703,
#  '2016_Q4_Electric': 7774,
#  '2016_Q4_Gas': 3691,
#  '2017_Q1_Electric': 7776,
#  '2017_Q1_Gas': 3486,
#  '2017_Q2_Electric': 7819,
#  '2017_Q2_Gas': 3489,
#  '2017_Q3_Electric': 7842,
#  '2017_Q3_Gas': 3491,
#  '2017_Q4_Electric': 10455,
#  '2017_Q4_Gas': 4662,
#  '2018_Q1_Electric': 7852,
#  '2018_Q1_Gas': 3499,
#  '2018_Q2_Electric': 7880,
#  '2018_Q2_Gas': 3502,
#  '2018_Q3_Electric': 7877,
#  '2018_Q3_Gas': 3503,
#  '2018_Q4_Electric': 7875,
#  '2018_Q4_Gas': 3496,
#  '2019_Q1_Electric': 7870,
#  '2019_Q1_Gas': 3499,
#  '2019_Q2_Electric': 7887,
#  '2019_Q2_Gas': 3499,
#  '2019_Q3_Electric': 7891,
#  '2019_Q3_Gas': 3489,
#  '2019_Q4_Electric': 7874,
#  '2019_Q4_Gas': 3490,
#  '2020_Q1_Electric': 7865,
#  '2020_Q1_Gas': 3493,
#  '2020_Q2_Electric': 7791,
#  '2020_Q2_Gas': 3461,
#  '2020_Q3_Electric': 7784,
#  '2020_Q3_Gas': 3459,
#  '2020_Q4_Electric': 7771,
#  '2020_Q4_Gas': 3456}

# %% [markdown]
# ## Filter only the Residential PG&E Customers

# %%
er = 'Elec- Residential'
gr = 'Gas- Residential'
to_keep = base_df[(base_df['CUSTOMERCLASS'] == er) | (base_df['CUSTOMERCLASS'] == gr)]
base_df['CUSTOMERCLASS'].unique()
# Out:
# array(['Elec- Agricultural', 'Elec- Commercial', 'Elec- Industrial',
#        'Elec- Residential', 'Gas- Commercial', 'Gas- Residential', 'Gas-',
#        'Gas- Agricultural'], dtype=object)

# %%
dest = 'cleaned_data/pge-monthly-consumption_2013-2020.csv'
to_keep.to_csv(dest)

# %%
to_keep.columns
# Out:
# Index(['ZIPCODE', 'MONTH', 'YEAR', 'CUSTOMERCLASS', 'COMBINED',
#        'TOTALCUSTOMERS', 'TOTALKWH', 'AVERAGEKWH', 'TOTALTHM', 'AVERAGETHM',
#        'TOTALTHERMS', 'AVERAGETHERMS'],
#       dtype='object')

# %%
print(to_keep.shape)
to_keep.head()
# Out:
# (154283, 12)
#       ZIPCODE  MONTH    YEAR      CUSTOMERCLASS COMBINED TOTALCUSTOMERS  \
# 4956  93101.0    1.0  2013.0  Elec- Residential        Y              0
# 4957  93101.0    2.0  2013.0  Elec- Residential        Y              0
# 4958  93101.0    3.0  2013.0  Elec- Residential        Y              0
# 4959  93105.0    1.0  2013.0  Elec- Residential        Y              0
# 4960  93105.0    2.0  2013.0  Elec- Residential        Y              0
#
#      TOTALKWH AVERAGEKWH TOTALTHM AVERAGETHM TOTALTHERMS AVERAGETHERMS
# 4956        0        NaN      NaN        NaN         NaN           NaN
# 4957        0        NaN      NaN        NaN         NaN           NaN
# 4958        0        NaN      NaN        NaN         NaN           NaN
# 4959        0        NaN      NaN        NaN         NaN           NaN
# 4960        0        NaN      NaN        NaN         NaN           NaN

# %% [markdown]
# ## Adding zipcode city locations and geometry (lat,long)

# %%
full = pd.read_csv('cleaned_data/pge-monthly-consumption_2013-2020.csv')
full.head()
# Out:
#    Unnamed: 0  ZIPCODE  MONTH    YEAR      CUSTOMERCLASS COMBINED  \
# 0        4956  93101.0    1.0  2013.0  Elec- Residential        Y
# 1        4957  93101.0    2.0  2013.0  Elec- Residential        Y
# 2        4958  93101.0    3.0  2013.0  Elec- Residential        Y
# 3        4959  93105.0    1.0  2013.0  Elec- Residential        Y
# 4        4960  93105.0    2.0  2013.0  Elec- Residential        Y
#
#   TOTALCUSTOMERS TOTALKWH AVERAGEKWH TOTALTHM AVERAGETHM TOTALTHERMS  \
# 0              0        0        NaN      NaN        NaN         NaN
# 1              0        0        NaN      NaN        NaN         NaN
# 2              0        0        NaN      NaN        NaN         NaN
# 3              0        0        NaN      NaN        NaN         NaN
# 4              0        0        NaN      NaN        NaN         NaN
#
#    AVERAGETHERMS
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# !ls data
# !ls data/us-zip-code-latitude-and-longitude
## This is the zip codes mapped to cities
zipcode_to_city_fn = "data/Bay Area Zip Codes + City Name - Sheet1.csv"
zipcodes_city_df = pd.read_csv(zipcode_to_city_fn)
display(zipcodes_city_df.head())

## this is the geographic data in a shapefile
zipcodes_to_latlong_shp_fn = "data/us-zip-code-latitude-and-longitude"
zipcodes_to_latlong_gdf = gpd.read_file(zipcodes_to_latlong_shp_fn)
display(zipcodes_to_latlong_gdf.head())
# Out:
# Bay Area Zip Codes + City Name - Sheet1.csv
# PGE
# us-zip-code-latitude-and-longitude
# us-zip-code-latitude-and-longitude.csv
# us-zip-code-latitude-and-longitude.zip
# us-zip-code-latitude-and-longitude.dbf us-zip-code-latitude-and-longitude.shp
# us-zip-code-latitude-and-longitude.prj us-zip-code-latitude-and-longitude.shx
#    Zip Code        City
# 0     94002     Belmont
# 1     94005    Brisbane
# 2     94010  Burlingame
# 3     94014   Daly City
# 4     94015   Daly City
#      zip             city state   latitude   longitude  timezone  dst  \
# 0  95717         Gold Run    CA  39.177026 -120.845100      -8.0  1.0
# 1  94564           Pinole    CA  37.997509 -122.292080      -8.0  1.0
# 2  91605  North Hollywood    CA  34.208142 -118.401100      -8.0  1.0
# 3  91102         Pasadena    CA  33.786594 -118.298662      -8.0  1.0
# 4  95019          Freedom    CA  36.935552 -121.779720      -8.0  1.0
#
#                       geometry
# 0  POINT (-120.84510 39.17703)
# 1  POINT (-122.29208 37.99751)
# 2  POINT (-118.40110 34.20814)
# 3  POINT (-118.29866 33.78659)
# 4  POINT (-121.77972 36.93555)

# %%
## First merge pge data with zipcode and cities to get City column
full_with_cities = pd.merge(left=full, right=zipcodes_city_df, left_on="ZIPCODE", right_on="Zip Code", how="inner").drop(["Unnamed: 0", "Zip Code"], axis=1).fillna(0)
display(full_with_cities.head())
# Out:
#    ZIPCODE  MONTH    YEAR      CUSTOMERCLASS COMBINED TOTALCUSTOMERS  \
# 0  94002.0    1.0  2013.0  Elec- Residential        N         10,489
# 1  94002.0    2.0  2013.0  Elec- Residential        N         10,503
# 2  94002.0    3.0  2013.0  Elec- Residential        N         10,496
# 3  94002.0    1.0  2013.0   Gas- Residential        N          9,227
# 4  94002.0    2.0  2013.0   Gas- Residential        N          9,248
#
#     TOTALKWH AVERAGEKWH TOTALTHM AVERAGETHM TOTALTHERMS  AVERAGETHERMS  \
# 0  5,819,025        555        0          0           0            0.0
# 1  4,789,653        456        0          0           0            0.0
# 2  4,779,129        455        0          0           0            0.0
# 3          0          0  866,555         94           0            0.0
# 4          0          0  639,613         69           0            0.0
#
#       City
# 0  Belmont
# 1  Belmont
# 2  Belmont
# 3  Belmont
# 4  Belmont

# %%
## Specify which columns have certain data types
convert_dict = {
    'ZIPCODE': str,
    'MONTH': int,
    'YEAR': int,
    'TOTALCUSTOMERS': int,
    'TOTALKWH': int,
    'AVERAGEKWH': int,
    'TOTALTHM': int,
    'AVERAGETHM': int,
    'TOTALTHERMS': int,
    'AVERAGETHERMS': int
    
}
## Drop columns we dont want to keep
bad_index = 'Unnamed: 0'
if bad_index in full_with_cities.columns:
    full_with_cities = full_with_cities.drop('Unnamed: 0', axis=1)
    
## Get rid of commas for the columns that are supposed to be integers
full_with_cities.replace(',', '', regex=True, inplace=True)
full_with_cities.fillna(0, inplace=True)

numerical_columns = ['TOTALCUSTOMERS', 'TOTALKWH', 'AVERAGEKWH', 'TOTALTHM', 'AVERAGETHM','TOTALTHERMS', 'AVERAGETHERMS']
for num_col in numerical_columns:
    full_with_cities[num_col] = full_with_cities[num_col].apply(pd.to_numeric, errors='coerce')

full_with_cities = full_with_cities.astype(convert_dict)

# %%
display(full_with_cities.head())
# Out:
#   ZIPCODE  MONTH  YEAR      CUSTOMERCLASS COMBINED  TOTALCUSTOMERS  TOTALKWH  \
# 0   94002      1  2013  Elec- Residential        N           10489   5819025
# 1   94002      2  2013  Elec- Residential        N           10503   4789653
# 2   94002      3  2013  Elec- Residential        N           10496   4779129
# 3   94002      1  2013   Gas- Residential        N            9227         0
# 4   94002      2  2013   Gas- Residential        N            9248         0
#
#    AVERAGEKWH  TOTALTHM  AVERAGETHM  TOTALTHERMS  AVERAGETHERMS     City
# 0         555         0           0            0              0  Belmont
# 1         456         0           0            0              0  Belmont
# 2         455         0           0            0              0  Belmont
# 3           0    866555          94            0              0  Belmont
# 4           0    639613          69            0              0  Belmont

# %%
# type(zipcodes_to_latlong_gdf["zip"][0])
# type(full_with_cities["ZIPCODE"][0])

# merge geopandas and pge+cities dataframes together
full_with_cities_gdf = pd.merge(left=zipcodes_to_latlong_gdf, right=full_with_cities, left_on="zip", right_on="ZIPCODE", how="inner")
full_with_cities_gdf.head()
# Out:
#      zip    city state   latitude  longitude  timezone  dst  \
# 0  94564  Pinole    CA  37.997509 -122.29208      -8.0  1.0
# 1  94564  Pinole    CA  37.997509 -122.29208      -8.0  1.0
# 2  94564  Pinole    CA  37.997509 -122.29208      -8.0  1.0
# 3  94564  Pinole    CA  37.997509 -122.29208      -8.0  1.0
# 4  94564  Pinole    CA  37.997509 -122.29208      -8.0  1.0
#
#                       geometry ZIPCODE  MONTH  ...      CUSTOMERCLASS  \
# 0  POINT (-122.29208 37.99751)   94564      1  ...  Elec- Residential
# 1  POINT (-122.29208 37.99751)   94564      2  ...  Elec- Residential
# 2  POINT (-122.29208 37.99751)   94564      3  ...  Elec- Residential
# 3  POINT (-122.29208 37.99751)   94564      1  ...   Gas- Residential
# 4  POINT (-122.29208 37.99751)   94564      2  ...   Gas- Residential
#
#   COMBINED TOTALCUSTOMERS  TOTALKWH  AVERAGEKWH  TOTALTHM  AVERAGETHM  \
# 0        N           6727   3787580         563         0           0
# 1        N           6725   3086143         459         0           0
# 2        N           6715   3091798         460         0           0
# 3        N           6166         0           0    562494          91
# 4        N           6172         0           0    388246          63
#
#    TOTALTHERMS  AVERAGETHERMS    City
# 0            0              0  Pinole
# 1            0              0  Pinole
# 2            0              0  Pinole
# 3            0              0  Pinole
# 4            0              0  Pinole
#
# [5 rows x 21 columns]

# %%
full_with_cities_gdf.plot();

# %%
full_with_cities_gdf.to_file("cleaned_data/pge-monthly-consumption_2013-2020_with-zipcodes-and-cities.shp")

# %%
# !ls data

gpd.read_file("data/CA_Counties").plot();
# Out:
# Bay Area Zip Codes + City Name - Sheet1.csv
# CA_Counties
# PGE
# us-zip-code-latitude-and-longitude
# us-zip-code-latitude-and-longitude.csv
# us-zip-code-latitude-and-longitude.zip
